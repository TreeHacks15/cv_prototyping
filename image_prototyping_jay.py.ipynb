# %%
import numpy
import scipy
import skimage
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from utils import load_test_images
images = load_test_images(num_images=3, bw=True)

# %% [markdown]
# # Step 1: Preprocess

# %%
from utils import preprocess_image
images = [preprocess_image(img) for img in images]
plt.imshow(images[0], cmap=plt.cm.gray)

# %%
print images[0]
# Out:
# [[ 0.70105637  0.70050863  0.70231007 ...,  0.65937894  0.65950531
#    0.65823846]
#  [ 0.70164274  0.70179277  0.70348002 ...,  0.66065232  0.66028612
#    0.65802528]
#  [ 0.70230421  0.70124521  0.70286312 ...,  0.66251939  0.66197404
#    0.66041556]
#  ...,
#  [ 0.18560192  0.1922988   0.20474242 ...,  0.62585412  0.62458778
#    0.62588241]
#  [ 0.17588137  0.19227609  0.20018647 ...,  0.62448569  0.6235378
#    0.62418179]
#  [ 0.17200946  0.18629652  0.20292331 ...,  0.62467328  0.62322742
#    0.62384256]]

# %% [markdown]
# # Step 2: Canny Edge Detection

# %%
from skimage import filter
edges = filter.canny(img, sigma=3.5) #sigma should be between like 3 and 5 for bold contours
plt.imshow(edges, cmap=plt.cm.gray)

# %% [markdown]
# # Step 3: Contour Detection

# %%
from
