# %%
import numpy
import scipy
import skimage
import matplotlib.pyplot as plt
# %pylab inline
from utils import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
images = load_test_images(num_images=3, bw=True)

# %% [markdown]
# # Step 1: Preprocess

# %%
img = images[0]
new_shape = tuple([s/10 for s in images[0].shape])

# %%
img = images[0] / 255.0
from skimage.transform import resize
img = resize(img, new_shape)
plt.imshow(denoised, cmap=plt.cm.gray)

# %%
from skimage.restoration import denoise_bilateral
denoised = denoise_bilateral(img, sigma_range=0.05, sigma_spatial=15)
plt.imshow(denoised, cmap=plt.cm.gray)

# %% [markdown]
# # Step 2: Canny Edge Detection

# %%
from skimage import filter
edges = filter.canny(img)
plt.imshow(edges, cmap=plt.cm.gray)

# %% [markdown]
# # Step 3: Contour Detection

# %%
from skimage import measure
contours = measure.find_contours(img, 0.8)

fig,ax = plt.figure()
ax.imshow(img, cmap=plt.cm.gray)
for n, contour in enumerate(contours):
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-cda86ef42bea> in <module>()
#       1 fig, ax = plt.subplots()
#       2 ax.imshow(images[0], interpolation='nearest', cmap=plt.cm.gray)
# ----> 3 print contours[1]
#       4 # for n, contour in enumerate(contours):
#       5 #     ax.plot(contour[:, 1], contour[:, 0], linewidth=2)
#
# IndexError: list index out of range
