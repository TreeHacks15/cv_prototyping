# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %pylab inline
import skimage
from skimage import data

from projective_transform import Projective_T, draw_quad
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Define Inputs: (image, corners)

# %%
#=====[ input vertices ]=====
image = data.text()
corners = np.array((
    (155, 15),
    (65, 40),
    (260, 130),
    (360, 95)
))
data = (image, corners)
plt.imshow(draw_quad(image, corners), cmap=plt.cm.gray)

# %% [markdown]
# ## Transform: (image, corners) -> surface contents

# %%
pt = Projective_T()
contents = pt.transform(data)
plt.imshow(contents, cmap=plt.cm.gray)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-10af36de0524> in <module>()
#       1 pt = Projective_T()
# ----> 2 contents = pt.transform(data)
#       3 plt.imshow(contents, cmap=plt.cm.gray)
#
# /Users/jayhack/CS/CV/TreeHacks15/cv_prototyping/projective_transform.py in transform(self, data)
#      49                 (image, corners) = data
#      50                 if not (type(corners) == np.ndarray) and (corners.shape == (4,2)):
# ---> 51                         raise TypeError("corners must be a 4x2 numpy ndarray; you passed %s" % str(corners.shape))
#      52
#      53                 #=====[ Step 2: Find projective transform       ]=====
#
# TypeError: corners must be a 4x2 numpy array; you passed (4, 2)

# %% [markdown]
# # Grab Surface

# %%
surface = pt.grab_surface(text_img)
plt.imshow(surface, cmap=plt.cm.gray)

# %% [markdown]
# # Project Info Image

# %%
coords = np.array((
                        (0, 110),
                        (0, 210),
                        (100, 210),
                        (100, 110)
            ))

info_img = np.ones((100,100))*0.5
warped = pt.project(text_img, info_img, coords)
wc = tf.warp_coords(pt.M, )
plt.imshow(warped, cmap=plt.cm.gray)
