# %%
import sys
sys.path.insert(0, '../')
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %pylab inline

from cv_prototyping import *
from cv_prototyping.rubiks import Cube
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load Images

# %%
frames = load_rubiks_video()
show_images(frames)

# %% [markdown]
# # Draw Edges

# %%
cube = Cube()
edge_images = [cube.draw_edges(frame) for frame in frames]
show_images(edge_images)

# %% [markdown]
# # Draw Contours

# %%
contour_images = [cube.draw_contours(frame) for frame in frames]
show_images(contour_images)
