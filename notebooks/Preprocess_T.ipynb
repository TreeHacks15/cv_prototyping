# %%
import numpy 
import scipy
import cv2
import skimage
import matplotlib.pyplot as plt
# %pylab inline

from preprocessing import Preprocess_T
from utils import load_test_images
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Load/Visualize Test Images

# %%
image = load_test_images(num_images=1, bw=False)[0]
plt.imshow(image, cmap=plt.cm.gray)

# %% [markdown]
# ## Transform

# %%
preprocess = Preprocess_T()
image = preprocess.transform(image)
plt.imshow(image, cmap=plt.cm.gray)
