# %% [markdown]
# # Get Content Pipeline
# Demonstrates the full pipline from raw image -> surface content

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %pylab inline
import skimage
import cv2

sys.path.insert(0, '../')
from cv_prototyping import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Raw data

# %%
images = load_test_images()
show_images(images)
# Out:
# hello, world!

# %% [markdown]
# # Extracted Region

# %%
oracle = CVOracle()
contents = [oracle.get_surface_contents(img) for img in images]

# %%
show_images(contents)

# %% [markdown]
# ## ON PAPER

# %%
import os
from cv2 import imread
image_paths = [p for p in os.listdir(os.path.join(os.getcwd(), '../data/image')) if p.startswith('IMG')]
image_paths = [os.path.join('../data/image', p) for p in image_paths]
images = [imread(p) for p in image_paths]
show_images(images)

# %%
oracle = CVOracle()
contents = [oracle.get_surface_contents(img) for img in images]

# %%
show_images(contents)

# %%
from .. import cv_prototyping
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f64ea0d732a5> in <module>()
# ----> 1 from .. import cv_prototyping
#
# ValueError: Attempted relative import in non-package
