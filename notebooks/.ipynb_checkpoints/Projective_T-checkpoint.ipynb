# %%
import sys
sys.path.insert(0, '../')
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %pylab inline
import skimage
from skimage import data

from cv_prototyping import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Define Inputs: (image, corners)

# %%
#=====[ input vertices ]=====
image = data.text()
corners = np.array((
    (155, 15),
    (65, 40),
    (260, 130),
    (360, 95)
))
data = (image, corners)
plt.imshow(draw_quad(image, corners), cmap=plt.cm.gray)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b70e858193c2> in <module>()
#       8 ))
#       9 data = (image, corners)
# ---> 10 plt.imshow(draw_quad(image, corners), cmap=plt.cm.gray)
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/cv_prototyping-0.1-py2.7.egg/cv_prototyping/utils.pyc in draw_quad(img, vx, value)
#      63     x = vx[:,0]
#      64     y = vx[:,1]
# ---> 65     rr, cc = draw.polygon(y, x)
#      66     img = img.copy()
#      67     img[rr,cc] = value
#
# NameError: global name 'draw' is not defined

# %% [markdown]
# ## Transform: (image, corners) -> surface contents

# %%
pt = Projective_T()
contents = pt.transform(data)
plt.imshow(contents, cmap=plt.cm.gray)
