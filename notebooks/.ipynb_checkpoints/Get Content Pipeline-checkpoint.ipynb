# %% [markdown]
# # Get Content Pipeline
# Demonstrates the full pipline from raw image -> surface content

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %pylab inline
import skimage
import cv2

from cv_prototyping import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Raw data

# %%
images = load_test_images()
show_images(images)

# %% [markdown]
# # Extracted Region

# %%
oracle = CVOracle()
contents = [oracle.get_surface_contents(img) for img in images]

# %%
show_images(contents)

# %% [markdown]
# ## ON PAPER

# %%
import os
from cv2 import imread
image_paths = [p for p in os.listdir(os.path.join(os.getcwd(), '../data/image') if p.startswith('IMG')]
print image_paths
# images = [imread(p) for p in image_paths if p.startswith('IMG')]
# Out:
#   File "<ipython-input-11-dae50ec89f35>", line 3
#     image_paths = [p for p in os.listdir(os.path.join(os.getcwd(), '../data/image') if p.startswith('IMG'))]
#                                                                                                           ^
# SyntaxError: invalid syntax
